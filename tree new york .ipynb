# %%
import pandas  as pd

# %%
tree_census = pd.read_csv('/content/2015-street-tree-census-tree-data.csv')
tree_census
# Out:
#         tree_id  block_id               created_at  tree_dbh  stump_diam  \
# 0        180683    348711  2015-08-27T00:00:00.000         3           0
# 1        200540    315986  2015-09-03T00:00:00.000        21           0
# 2        204026    218365  2015-09-05T00:00:00.000         3           0
# 3        204337    217969  2015-09-05T00:00:00.000        10           0
# 4        189565    223043  2015-08-30T00:00:00.000        21           0
# ...         ...       ...                      ...       ...         ...
# 298390   495037    408840  2015-12-03T00:00:00.000         6           0
# 298391   495039    408840  2015-12-03T00:00:00.000         7           0
# 298392   518420    409951  2015-12-15T00:00:00.000        10           0
# 298393   518737    409890  2015-12-15T00:00:00.000        11           0
# 298394   518752    409890  2015-12-15T00:00:00.000        13           0
#
#        curb_loc status health                           spc_latin  \
# ...

# %%
     tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census [['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other', 'brch_light', 'brch_shoe', 'brch_other']]

tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 298390   495037         6           0   OnCurb  Alive   Good
# 298391   495039         7           0   OnCurb  Alive   Good
# 298392   518420        10           0   OnCurb  Alive   Good
# 298393   518737        11           0   OnCurb  Alive   Fair
# 298394   518752        13           0   OnCurb  Alive   Poor
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum     NaN  NoDamage      NaN
# 1                        Quercus palustris     NaN    Damage   Stones
# ...

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health         14412
# spc_latin      14410
# steward       224777
# sidewalk       14411
# problems      202372
# root_stone         0
# root_grate         0
# root_other         0
# trunk_wire         0
# trnk_light         0
# trnk_other         0
# brch_light         0
# brch_shoe          0
# brch_other         0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 57       187807         0           0   OnCurb   Dead    NaN       NaN
# 196      208322        10           0   OnCurb   Dead    NaN       NaN
# 209      209058         6           0   OnCurb   Dead    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 298326   515478        13           0   OnCurb   Dead    NaN       NaN
# 298334   470253         1           0   OnCurb   Dead    NaN       NaN
# 298346   502597         0          10   OnCurb  Stump    NaN       NaN
# 298350   463487         0           4   OnCurb  Stump    NaN       NaN
# 298351   510953         4           0   OnCurb   Dead    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  298395.000000  298395.000000  298395.000000
# mean   337612.699760      10.956300       0.435161
# std     95814.089984       8.668893       3.301211
# min         7.000000       0.000000       0.000000
# 25%    259510.500000       4.000000       0.000000
# 50%    338157.000000       9.000000       0.000000
# 75%    417223.500000      15.000000       0.000000
# max    570264.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'tree_id'}>,
#         <Axes: title={'center': 'tree_dbh'}>],
#        [<Axes: title={'center': 'stump_diam'}>, <Axes: >]], dtype=object)

# %%
big_trees = tree_census_subset[tree_census_subset['tree_dbh']>50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 286324   468900        74           0          OnCurb  Alive   Good
# 288264   506458       106           0          OnCurb  Alive   Good
# 289502   484877        53           0          OnCurb  Alive   Good
# 294209   500075       147           0          OnCurb  Alive   Poor
# 297538   517868        57           0          OnCurb  Alive   Good
#
#                                  spc_latin steward  sidewalk problems  \
# 2405                       Quercus bicolor    1or2    Damage      NaN
# ...

# %%
big_trees[['tree_id','tree_dbh']].plot(kind = 'scatter',x='tree_id',y='tree_dbh',figsize=(20,10) )
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind = 'bar', figsize=(23,10))
# Out:
# <Axes: xlabel='spc_latin'>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# steward
# 1or2       64039
# 3or4        8792
# 4orMore      787
# Name: count, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# curb_loc
# OnCurb            287048
# OffsetFromCurb     11347
# Name: count, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# curb_loc
# OnCurb            287048
# OffsetFromCurb     11347
# Name: count, dtype: int64

# %%
stumps = tree_census_subset[tree_census_subset['status']=='stump' ]
stumps
# Out:
# Empty DataFrame
# Columns: [tree_id, tree_dbh, stump_diam, curb_loc, status, health, spc_latin, steward, sidewalk, problems, root_stone, root_grate, root_other, trunk_wire, trnk_light, trnk_other, brch_light, brch_shoe, brch_other]
# Index: []

# %%
deads= tree_census_subset[tree_census_subset['status']=='deads']
deads
# Out:
# Empty DataFrame
# Columns: [tree_id, tree_dbh, stump_diam, curb_loc, status, health, spc_latin, steward, sidewalk, problems, root_stone, root_grate, root_other, trunk_wire, trnk_light, trnk_other, brch_light, brch_shoe, brch_other]
# Index: []

# %%
# tree__problems = tree_census_subset[['root_stone',
#                                      'root_grate','root_other','trunk_wire','trnk_light','trnk_other',
#                                      'brch_light','brch_shoe','brch_other']]
# tree_problems


tree__problems = tree_census_subset[['root_stone',
                                     'root_grate','root_other','trunk_wire','trnk_light','trnk_other',
                                     'brch_light','brch_shoe','brch_other']]
tree__problems # Make sure to display the correct variable name
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 298390         No         No         No         No         No         No
# 298391         No         No         No         No         No         No
# 298392         No         No         No         No         No         No
# 298393         No         No         No         No         No         No
# 298394         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
# tree_problems.apply(pd.series.value_counts)
# Fix the typo in the variable name
tree_problems = tree_census_subset[['root_stone',
                                     'root_grate','root_other','trunk_wire','trnk_light','trnk_other',
                                     'brch_light','brch_shoe','brch_other']]
# Rename the variable 'series' to something else to avoid conflicts
tree_data = series

# Apply the value_counts function correctly
tree_problems.apply(pd.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       241556      296688      285300      293039      297955      284806
# Yes       56839        1707       13095        5356         440       13589
#
#      brch_light  brch_shoe  brch_other
# No       271058     298207      287105
# Yes       27337        188       11290
